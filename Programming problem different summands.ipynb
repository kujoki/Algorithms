# %% [markdown]
# ![Screenshot%20from%202022-09-09%2013-06-21.png](attachment:Screenshot%20from%202022-09-09%2013-06-21.png)

# %%
n = int(input())
k =1 
a = []
s = 0
for i in range(1,n+1):
    s+=i
    a.append(i)
    if s == n:
        final = s
        break
    elif s > n:
        s = s - (a[-1] + a[-2])
        a = a[:-2]
        a.append(n - s)
        break
print(len(a))
for i in a:
    print (i,end=' ')
# Out:
# 4
# 2
# 1 3
